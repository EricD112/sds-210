# %% [markdown]
# **Project 3: Urban Heat**
#
# *Project Content*
# Access and analyze Landsat-based time series data.
# Compare Land Surface Temperature (LST) and vegetation indicies.
# Calculate and compare changes in LST and vegetation over time.
# Summarize and visualize the climatic trends for Zurich.
#
# *Suggested Tasks*
# How drastically has the average land surface temperature changed since the mid-1980s?
# Is there a measurable correlation between warmer urban areas and lower vegetation or high build-up signals?
# How do spectral indices help us interpret the physical causes of these heat patterns?
# Are specific neighborhoods within the city warming faster than others?
#
# *1. From Question to Workflow*
# Start with focused question
# Turn the question into steps
#
# *2. Planning the Analysis*
# What are the exact questions
# What data will be used
# What should the output look like
# Possible difficulties
# Sketch the workflow
#
# *3. Building an Incremental Solution*
# Start simple
# Improve the layers
# Separate core tasks
#
# *3. Testing, Debugging and Refining*
# Test small parts first
# Read errors carefully
# Refine after it works

# %% [markdown]
# **Workflow**
#
# *Questions (old)*
# Which neighbourhoods, if any, are warming faster than others?
# Do they correlate with lower vegetation?
# How does the proximity to water affect the heat?
# Is there a difference between central and peripheral neighbourhoods?
#
# *Questions*
# How drastically has the average land surface temperature changed since the mid-1980s?
# Which neighbourhoods, if any, are warming faster than others?
# Do they correlate with lower vegetation?
# How do spectral indices help us interpret the physical causes of these heat patterns?
#
# *Roadmap*
# 1. Questions:
# 	See above
# 2. Data:
# 	Landsat dataset, supplied by course
# 	Dataset for neighbourhoods (Quartiere) of Zürich
# 3. Output:
# 	Map showing changes in heat over time with Quartier polygons (and Coloured circles for mean).
# 	(Map showing vegetation)
# 	Charts showing heat over time, for mean vegetation, water proximity and periphery, as well as combined score, by Quartier
# 	Table showing heat, heat change, vegetation, water proximity and periphery, as well as combined score, by Quartier
# 4. Possible Difficulties
# 	Calculating vegetation, periphericity and water proximity
